# %%
from Transformer import BertLayer, TransformerModel
from STOTModel import STOT
from LSTM import LSTMModel
from ParagonFull import*

# %%
import LSTM
from LSTM import LSTMModel
import importlib
importlib.reload(LSTM)
# Out:
# <module 'LSTM' from '/Users/jorgemy/Desktop/School/CurrentSem/CSCI5122/Project/neural_networks_project/LSTM.py'>

# %%
from datasets import load_dataset

# load dataset from huggingface
ds = load_dataset("amaai-lab/DisfluencySpeech")

train = ds["train"]
val  = ds["validation"]
test = ds["test"]

# %%
mod1 = LSTMModel(train=train,val=val,test=test) 
mod1.run(20)
# Out:
# /Users/jorgemy/Desktop/School/schoool/lib/python3.13/site-packages/keras/src/layers/core/embedding.py:100: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ (None, 6517, 32)       │       208,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_6 (Bidirectional) │ (None, 6517, 200)      │       106,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_7 (Bidirectional) │ (None, 6517, 100)      │       100,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6517, 3)        │           303 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 415,647 (1.59 MB)
#  Trainable params: 415,647 (1.59 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - loss: 0.6280 - sparse_categorical_accuracy: 0.8324 - val_loss: 0.2836 - val_sparse_categorical_accuracy: 0.8801
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - loss: 0.4111 - sparse_categorical_accuracy: 0.8783 - val_loss: 0.2829 - val_sparse_categorical_accuracy: 0.8744
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - loss: 0.3766 - sparse_categorical_accuracy: 0.8895 - val_loss: 0.2857 - val_sparse_categorical_accuracy: 0.8762
# Epoch 4/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - loss: 0.3552 - sparse_categorical_accuracy: 0.8962 - val_loss: 0.2910 - val_sparse_categorical_accuracy: 0.8728
# Epoch 5/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - loss: 0.3322 - sparse_categorical_accuracy: 0.9030 - val_loss: 0.2790 - val_sparse_categorical_accuracy: 0.8827
# Epoch 6/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - loss: 0.3175 - sparse_categorical_accuracy: 0.9064 - val_loss: 0.2712 - val_sparse_categorical_accuracy: 0.8882
# Epoch 7/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - loss: 0.3009 - sparse_categorical_accuracy: 0.9123 - val_loss: 0.2755 - val_sparse_categorical_accuracy: 0.8870
# Epoch 8/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - loss: 0.2865 - sparse_categorical_accuracy: 0.9168 - val_loss: 0.2880 - val_sparse_categorical_accuracy: 0.8804
# Epoch 9/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - loss: 0.2716 - sparse_categorical_accuracy: 0.9200 - val_loss: 0.2627 - val_sparse_categorical_accuracy: 0.8970
# Epoch 10/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - loss: 0.2570 - sparse_categorical_accuracy: 0.9254 - val_loss: 0.2758 - val_sparse_categorical_accuracy: 0.8919
# Epoch 11/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - loss: 0.2430 - sparse_categorical_accuracy: 0.9291 - val_loss: 0.2820 - val_sparse_categorical_accuracy: 0.8904
# Epoch 12/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - loss: 0.2292 - sparse_categorical_accuracy: 0.9332 - val_loss: 0.3069 - val_sparse_categorical_accuracy: 0.8799
# Epoch 13/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - loss: 0.2160 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.2915 - val_sparse_categorical_accuracy: 0.8930
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2110 - sparse_categorical_accuracy: 0.9168
# Test loss: 0.21100126206874847
# Test accuracy: 0.916841447353363
#
# -------------
#
# Testing on the sentence: i, uh, don't, i don't think that is true
# Expected: i don't think that is true
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# Result: don't, i don't think that is true
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# F1 score: 0.7671935070482699
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.73      0.81      0.77      1103
#            2       0.96      0.94      0.95      5561
#
#     accuracy                           0.92      6664
#    macro avg       0.84      0.88      0.86      6664
# weighted avg       0.92      0.92      0.92      6664

# %%
mod1.plot_seq_lengths()
# Out:
# First few lengths: [28, 19, 21, 34, 29]

# %%
mod1.print_props()
# Out:
# Percentage 0 is 0.30495555555555554
# Percentage 1 is 0.11581111111111111
# Percentage 2 is 0.5792333333333334

# %%
mod2 = TransformerModel(train=train,val=val,test=test)
mod2.run(10)
# Out:
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_ids           │ (None, 40)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_mask      │ (None, 40)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bert_layer          │ (None, 40, 3072)  │          0 │ input_ids[0][0],  │
# │ (BertLayer)         │                   │            │ attention_mask[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 40, 3072)  │          0 │ bert_layer[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, 40, 256)   │    786,688 │ dropout[0][0]     │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 40, 256)   │          0 │ time_distributed… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_1  │ (None, 40, 3)     │        771 │ dropout_1[0][0]   │
# │ (TimeDistributed)   │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 787,459 (3.00 MB)
#  Trainable params: 787,459 (3.00 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 162s 277ms/step - loss: 0.2760 - sparse_categorical_accuracy: 0.8965 - val_loss: 0.1723 - val_sparse_categorical_accuracy: 0.9364
# Epoch 2/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 155s 275ms/step - loss: 0.1693 - sparse_categorical_accuracy: 0.9351 - val_loss: 0.1571 - val_sparse_categorical_accuracy: 0.9394
# Epoch 3/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 151s 268ms/step - loss: 0.1529 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.1501 - val_sparse_categorical_accuracy: 0.9403
# Epoch 4/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 151s 268ms/step - loss: 0.1444 - sparse_categorical_accuracy: 0.9415 - val_loss: 0.1456 - val_sparse_categorical_accuracy: 0.9425
# Epoch 5/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 186s 330ms/step - loss: 0.1397 - sparse_categorical_accuracy: 0.9427 - val_loss: 0.1424 - val_sparse_categorical_accuracy: 0.9432
# Epoch 6/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 303s 537ms/step - loss: 0.1353 - sparse_categorical_accuracy: 0.9441 - val_loss: 0.1394 - val_sparse_categorical_accuracy: 0.9443
# Epoch 7/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 277s 492ms/step - loss: 0.1321 - sparse_categorical_accuracy: 0.9455 - val_loss: 0.1372 - val_sparse_categorical_accuracy: 0.9457
# Epoch 8/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 214s 380ms/step - loss: 0.1285 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.1356 - val_sparse_categorical_accuracy: 0.9453
# Epoch 9/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 242s 430ms/step - loss: 0.1269 - sparse_categorical_accuracy: 0.9469 - val_loss: 0.1339 - val_sparse_categorical_accuracy: 0.9449
# Epoch 10/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 284s 506ms/step - loss: 0.1241 - sparse_categorical_accuracy: 0.9477 - val_loss: 0.1325 - val_sparse_categorical_accuracy: 0.9463
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 464ms/step - loss: 0.1088 - sparse_categorical_accuracy: 0.9557
# Test loss: 0.10879139602184296
# Test accuracy: 0.9557000994682312
#
# -------------
#
# Testing on the sentence: i, uh, don't, i don't think that is true
# Expected: i don't think that is true
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Result: i don't think that is true
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 594ms/step
# 2025-12-02 18:31:29.184033: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# F1 score: 0.7981776765375854
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.84      0.76      0.80      1156
#            2       0.95      0.97      0.96      6060
#
#     accuracy                           0.94      7216
#    macro avg       0.90      0.87      0.88      7216
# weighted avg       0.94      0.94      0.94      7216

# %%
APIKey = "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"
stot = STOT(model=mod2, API=APIKey,audio_predictions=[],audio_data=list(test["audio"]))
# Out:
# Device set to use mps:0

# %%
stot.eval_single_input(0)
# Out:
# Audio Transcription: yeah . well , rabbits are darling . that would be fun if you could get them trained . otherwise they're pretty smelly .
# True Transcription: yeah . well , rabbits are darling . that would be fun if you could get them trained . otherwise they're pretty smelly .
# Word Error Rate: 0.0
# -------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# Transcription After Filter: yeah. rabbits are darling. that would be fun if you could get them trained. otherwise they're pretty smelly.
# Filtered Gold Text: yeah. rabbits are darling. that would be fun if you could get them trained. otherwise they're pretty smelly.
# True Filter: yeah. rabbits are darling. that would be fun if you could get them trained. otherwise they're pretty smelly.

# %%
mod3 = TransformerModel(train=train,val=val,test=test)
mod3.run(10)
